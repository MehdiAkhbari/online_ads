# %%
import numpy as np
import pandas as pd
from econml.dml import CausalForestDML
import matplotlib.pyplot as plt
import os
from sklearn.linear_model import Lasso, LassoCV, LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.base import BaseEstimator
from econml.sklearn_extensions.model_selection import GridSearchCVList
import time
import joblib
import multiprocessing
import pickle




import config
from utils import *


n_processes = 8

criteria = config.my_criteria


# For ignoring the warnings
from warnings import simplefilter, filterwarnings
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
filterwarnings("ignore", category=UserWarning)
pd.options.mode.chained_assignment = None



base_ad = 50
max_adv_rank = 100
max_visit_no = 100 # max number of page visits by each user

split_no_1 = config.split_no_1
split_no_2 = config.split_no_2


# read data
data = pd.read_stata(f"..\\data\\Full Model\\Simulation Data - Full Model - Split {split_no_1} {split_no_2} - Subsample.dta")
vals_data = pd.read_stata(f"..\\data\\Full Model\\Advertiser Valuations.dta")
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
# rank 20 model loaded!
# rank 40 model loaded!
# rank 60 model loaded!
# rank 80 model loaded!
# rank 100 model loaded!
# rank 20 model loaded!
# rank 40 model loaded!
# rank 60 model loaded!
# rank 80 model loaded!
# rank 100 model loaded!
# rank 20 model loaded!
# rank 40 model loaded!
# rank 60 model loaded!
# rank 80 model loaded!
# rank 100 model loaded!

# %%
data = pd.read_stata(f"..\\data\\Full Model\\Simulation Data - Full Model - Split {split_no_1} {split_no_2} - Subsample.dta")
data = data[data['global_token_new'] <= 200]

# %%
def simulate_duopoly(data, vals_data, criteria):
    # file_name = f"data_chunk_{chunk}"
    # create empty columns in the dataframe to fill later
    create_chosen_split_ad_vars(data)

    
    # print(f"\n\n\n=======> Chunk #{chunk}")
    start_time_2 = time.perf_counter()


    for i in range(1, max_visit_no + 1):

        start_time_1 = time.perf_counter()
        print(f"\n\n --->Repeat #{i}:")
        # 1) calculate treatment effects, and base ad ctr, then sum them sup and create ctrs for all ads
        start_time = time.perf_counter()
        # a) calc TEs and CTRs on s1
        calc_split_tes(data, split_no=config.split_no_1, user_visit_no=i, ranks_list=config.ranks_list)
        calc_base_ad_split_ctr(data, split_no=config.split_no_1, user_visit_no=i)
        calc_split_ctrs(data, vals_data, split_no=config.split_no_1, user_visit_no=i, ranks_list=config.ranks_list)

        # b) calc TEs and CTRs on s2
        calc_split_tes(data, split_no=config.split_no_2, user_visit_no=i, ranks_list=config.ranks_list)
        calc_base_ad_split_ctr(data,split_no=config.split_no_2, user_visit_no=i)
        calc_split_ctrs(data, vals_data, split_no=config.split_no_2, user_visit_no=i, ranks_list=config.ranks_list)

        finish_time = time.perf_counter()
        print(f"Step 1 of repeat {i} finished in {finish_time - start_time} seconds!")
        # 2) determine what ads are chosen
        start_time = time.perf_counter()
        # find the optimal ads and save them and their corresponding ctr's in the dataframe
        # on s1
        create_chosen_ad_columns_split(data, split_no=config.split_no_1, user_visit_no=i, criteria=criteria)
        

        # on s2
        create_chosen_ad_columns_split(data, split_no=config.split_no_2, user_visit_no=i, criteria=criteria)
        finish_time = time.perf_counter()
        print(f"Step 2 of repeat {i} finished in {finish_time - start_time} seconds!")

        # 3) Update repeats
        start_time = time.perf_counter()

        # update_repeats_on_main_and_split_sqrt_n(data, user_visit_no=i)
        update_repeats_on_main_and_split(data, split_no=config.split_no_1, user_visit_no=i)
        update_repeats_on_main_and_split(data, split_no=config.split_no_2, user_visit_no=i)
        finish_time = time.perf_counter()
        print(f"Step 3 of repeat {i} finished in {finish_time - start_time} seconds!")

        # 4) Update clicks
        start_time = time.perf_counter()

        update_clicks_on_main_and_split(data, split_no=config.split_no_1, user_visit_no=i)
        update_clicks_on_main_and_split(data, split_no=config.split_no_2, user_visit_no=i)
        # update_clicks_on_main_and_split_sqrt_n(data, user_visit_no=i)     

        finish_time = time.perf_counter()
        print(f"Step 4 of repeat {i} finished in {finish_time - start_time} seconds!")
        finish_time_1 = time.perf_counter()
        print(f"Repeat {i}  finished in  {finish_time_1 - start_time_1} seconds!")

    finish_time_2 = time.perf_counter()
    # data.to_stata(("..\\results\\Full Model\\Simulation Results\\Simluation Results - Split {split_no_1} {split_no_2}.dta"))
    print(f"All Repeats finished in {finish_time_2 - start_time_2} seconds!")
    return data


def simulate_and_save_chunk(chunk_data, chunk_id, criteria):
    
    chunk_data = simulate_duopoly(chunk_data, vals_data, criteria)
    # Create a unique filename for the chunk
    if criteria == "CTR":
        filename = f"..\\results\\Full Model\\Simulation Results\\Simluation Results - Split {split_no_1} {split_no_2} - chunk {chunk_id+1}.dta"
    if criteria == "revenue":
        filename = f"..\\results\\Full Model\\Simulation Results\\Simluation Results - Split {split_no_1} {split_no_2} Revenue Max - chunk {chunk_id+1}.dta"

    # Save the processed DataFrame to DTA
    chunk_data.to_stata(filename)

# %%
def find_optimal_split_ads(row, criteria):
    """
    This functions calculates optimal ads (based on highest treatment effects) to be shown to the impression in each row. based on the calculated treatment effects y_i s
    Inputs: 
        - row: the row of the dataframe that it is applied to
        it has to include indices y_cols and "ads_on_page" (determines how many ads to choose)
    
    Returns: 
        - chosen_ads: a list of ads to be shown
        - chosen_ad_ys: a list of the corresponding treatment effects
    """
    chosen_ad_ys_actual = []
    chosen_ad_revs_actual = []
    y_cols = row.filter(regex=r'^y_.*_s$', axis=0)
    rev_cols = row.filter(regex=r'^rev_.*_s', axis=0)

    # sort the values by the value of the criteria
    if criteria == "CTR":
        sorted_ads = row[y_cols.index].sort_values(ascending=False).index.to_list()
        l = min(row['ads_on_page'], config.max_ads_per_page)    # number of ads to be shown on each visit
        chosen_ads = sorted_ads[0 : l]
        chosen_ads = [int(element[2: -2]) for element in chosen_ads] # this will turn y_25_s into 25!

    if criteria == "revenue":
        sorted_ads = row[rev_cols.index].sort_values(ascending=False).index.to_list()
        l = min(row['ads_on_page'], config.max_ads_per_page)    # number of ads to be shown on each visit  
        chosen_ads = sorted_ads[0 : l]
        chosen_ads = [int(element[4: -2]) for element in chosen_ads] # this will turn rev_25_s into 25!


    # creates a list of chosen ad ranks
    chosen_ad_ys_split = y_cols.sort_values(ascending=False).values[0:l]
    chosen_ad_revs_split = rev_cols.sort_values(ascending=False).values[0:l]

    for chosen_ad in chosen_ads:
        y_var_name = f"y_{chosen_ad}"
        chosen_ad_ys_actual.append(row[y_var_name])

        rev_var_name = f"rev_{chosen_ad}"
        chosen_ad_revs_actual.append(row[rev_var_name])

    return chosen_ads, chosen_ad_ys_split, chosen_ad_revs_split, chosen_ad_ys_actual, chosen_ad_revs_actual



    
def create_chosen_ad_columns_split(data, split_no, user_visit_no, criteria): 
    """
    This function finds the optimal ads for the subsection of "data" for which user_visit_no == user_visit_no
    The chosen ads and their corresponding click rates are saved in 'chosen_ad_{ad}' and 'chosen_ad_y_{ad}'
    """
    # select treatment effect columns
    # te_cols = data.loc[0: 1, :].filter(regex="^te_", axis=1).columns
    # select ctr columns:
    # y_cols = data.loc[0: 1, :].filter(regex="^y_", axis=1).columns
    y_cols = data.columns[data.columns.str.match(r"^y_.*_s$")]

    for index, row in data[(data['user_visit_no'] == user_visit_no) & (data['split'] == split_no)].iterrows():
        
        chosen_ads, chosen_ad_ys_split, chosen_ad_revs_split, chosen_ad_ys_actual, chosen_ad_revs_actual = find_optimal_split_ads(row, criteria)
        chosen_ads = [int(element) for element in chosen_ads]
        l = len(chosen_ads)
        last_chosen_ad_name = f"chosen_ad_{l}"
        # last_chosen_ad_te_name = f"chosen_ad_te_{l}"
        last_chosen_ad_y_name_split = f"chosen_ad_y_{l}_s"
        last_chosen_ad_y_name_actual = f"chosen_ad_y_{l}"
        last_chosen_ad_rev_name_split = f"chosen_ad_rev_{l}_s"
        last_chosen_ad_rev_name_actual = f"chosen_ad_rev_{l}"
        data.loc[index, 'chosen_ad_1': last_chosen_ad_name] = chosen_ads
        data.loc[index, 'chosen_ad_y_1_s' : last_chosen_ad_y_name_split] = chosen_ad_ys_split
        data.loc[index, 'chosen_ad_rev_1_s' : last_chosen_ad_rev_name_split] = chosen_ad_revs_split
        data.loc[index, 'chosen_ad_y_1' : last_chosen_ad_y_name_actual] = chosen_ad_ys_actual
        data.loc[index, 'chosen_ad_rev_1' : last_chosen_ad_rev_name_actual] = chosen_ad_revs_actual
        data.at[index, 'num_ads'] = int(l)
        # if index % 10000 == 0:
        #     print(f"index {index} done!")

# %%
simulate_duopoly(data, vals_data, criteria)
# Out:
#  --->Repeat #1:
# finished calculating te's for rank 101 in 38.38664640000002 seconds
# finished calculating te's for rank 101 in 37.81934490000003 seconds
# Step 1 of repeat 1 finished in 83.03002319999996 seconds!
# y_50_s     0.005163
# y_1_s      0.006136
# y_2_s       0.00559
# y_3_s      0.005154
# y_4_s      0.005629
#              ...
# y_96_s     0.004157
# y_98_s     0.004973
# y_99_s     0.006585
# y_100_s    0.006478
# y_101_s    0.005267
# Name: 5, Length: 96, dtype: object
# rev_1_s      0.015206
# rev_2_s      0.009196
# rev_3_s      0.010083
# rev_4_s      0.027165
# rev_5_s      0.009474
#                ...
# rev_96_s     0.012547
# rev_98_s     0.018905
# rev_99_s     0.049308
# rev_100_s    0.027148
# rev_101_s    0.018059
# Name: 5, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s          0.0
# y_1_s      0.000947
# y_2_s      0.000409
# y_3_s      0.000334
# y_4_s      0.000465
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.001422
# y_100_s    0.001315
# y_101_s         0.0
# Name: 9, Length: 96, dtype: object
# rev_1_s      0.002345
# rev_2_s      0.000673
# rev_3_s      0.000653
# rev_4_s      0.002246
# rev_5_s           0.0
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.010649
# rev_100_s    0.005511
# rev_101_s         0.0
# Name: 9, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_20_s', 'rev_68_s', 'rev_44_s', 'rev_38_s', 'rev_66_s', 'rev_87_s', 'rev_100_s', 'rev_83_s', 'rev_75_s', 'rev_78_s', 'rev_30_s']
# y_50_s     0.001685
# y_1_s       0.00281
# y_2_s      0.001934
# y_3_s      0.001838
# y_4_s      0.002151
#              ...
# y_96_s     0.000679
# y_98_s     0.001496
# y_99_s     0.003107
# y_100_s       0.003
# y_101_s    0.001806
# Name: 10, Length: 96, dtype: object
# rev_1_s      0.006962
# rev_2_s      0.003181
# rev_3_s      0.003596
# rev_4_s       0.01038
# rev_5_s      0.002335
#                ...
# rev_96_s     0.002049
# rev_98_s     0.005685
# rev_99_s     0.023267
# rev_100_s    0.012573
# rev_101_s    0.006192
# Name: 10, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_70_s', 'rev_38_s', 'rev_99_s', 'rev_87_s', 'rev_66_s', 'rev_20_s']
# y_50_s          0.0
# y_1_s      0.001115
# y_2_s      0.000225
# y_3_s       0.00035
# y_4_s      0.000465
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.001422
# y_100_s    0.001315
# y_101_s    0.000232
# Name: 11, Length: 96, dtype: object
# rev_1_s      0.002762
# rev_2_s       0.00037
# rev_3_s      0.000685
# rev_4_s      0.002246
# rev_5_s           0.0
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.010649
# rev_100_s    0.005511
# rev_101_s    0.000795
# Name: 11, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_20_s', 'rev_68_s', 'rev_44_s', 'rev_38_s', 'rev_66_s', 'rev_87_s']
# y_50_s     0.001386
# y_1_s      0.002064
# y_2_s      0.001726
# y_3_s      0.001535
# y_4_s      0.001852
#              ...
# y_96_s      0.00038
# y_98_s     0.001196
# y_99_s     0.002808
# y_100_s    0.002701
# y_101_s    0.001284
# Name: 30, Length: 96, dtype: object
# rev_1_s      0.005114
# rev_2_s      0.002839
# rev_3_s      0.003002
# rev_4_s      0.008936
# rev_5_s      0.003156
#                ...
# rev_96_s     0.001147
# rev_98_s     0.004548
# rev_99_s     0.021028
# rev_100_s     0.01132
# rev_101_s    0.004404
# Name: 30, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.002538
# y_1_s      0.003227
# y_2_s       0.00297
# y_3_s       0.00252
# y_4_s      0.003003
#              ...
# y_96_s     0.001532
# y_98_s     0.002348
# y_99_s      0.00396
# y_100_s    0.003853
# y_101_s     0.00261
# Name: 38, Length: 96, dtype: object
# rev_1_s      0.007995
# rev_2_s      0.004886
# rev_3_s       0.00493
# rev_4_s      0.014495
# rev_5_s      0.005353
#                ...
# rev_96_s     0.004623
# rev_98_s     0.008926
# rev_99_s     0.029651
# rev_100_s    0.016146
# rev_101_s    0.008949
# Name: 38, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004283
# y_1_s      0.005795
# y_2_s      0.004734
# y_3_s      0.004487
# y_4_s      0.004749
#              ...
# y_96_s     0.003277
# y_98_s     0.004094
# y_99_s     0.005706
# y_100_s    0.005598
# y_101_s    0.004706
# Name: 43, Length: 96, dtype: object
# rev_1_s       0.01436
# rev_2_s      0.007788
# rev_3_s      0.008777
# rev_4_s      0.022919
# rev_5_s      0.007206
#                ...
# rev_96_s     0.009891
# rev_98_s     0.015561
# rev_99_s     0.042721
# rev_100_s    0.023462
# rev_101_s    0.016137
# Name: 43, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_70_s', 'rev_38_s', 'rev_15_s']
# y_50_s     0.000755
# y_1_s      0.002086
# y_2_s      0.000921
# y_3_s      0.000753
# y_4_s       0.00122
#              ...
# y_96_s          0.0
# y_98_s     0.000565
# y_99_s     0.002177
# y_100_s     0.00207
# y_101_s    0.000814
# Name: 46, Length: 96, dtype: object
# rev_1_s      0.005168
# rev_2_s      0.001516
# rev_3_s      0.001473
# rev_4_s      0.005889
# rev_5_s      0.000622
#                ...
# rev_96_s          0.0
# rev_98_s     0.002147
# rev_99_s       0.0163
# rev_100_s    0.008674
# rev_101_s    0.002792
# Name: 46, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_38_s', 'rev_20_s']
# y_50_s     0.011025
# y_1_s      0.012055
# y_2_s      0.011161
# y_3_s      0.011278
# y_4_s      0.011491
#              ...
# y_96_s     0.010019
# y_98_s     0.010835
# y_99_s     0.012447
# y_100_s     0.01234
# y_101_s    0.011384
# Name: 50, Length: 96, dtype: object
# rev_1_s      0.029872
# rev_2_s      0.018362
# rev_3_s      0.022063
# rev_4_s      0.055457
# rev_5_s      0.019819
#                ...
# rev_96_s      0.03024
# rev_98_s     0.041188
# rev_99_s       0.0932
# rev_100_s    0.051714
# rev_101_s    0.039036
# Name: 50, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004805
# y_1_s      0.005372
# y_2_s      0.005166
# y_3_s      0.004812
# y_4_s      0.005271
#              ...
# y_96_s     0.003799
# y_98_s     0.004616
# y_99_s     0.006227
# y_100_s     0.00612
# y_101_s    0.004962
# Name: 53, Length: 96, dtype: object
# rev_1_s      0.013312
# rev_2_s      0.008499
# rev_3_s      0.009414
# rev_4_s      0.025438
# rev_5_s      0.009189
#                ...
# rev_96_s     0.011467
# rev_98_s     0.017545
# rev_99_s     0.046628
# rev_100_s    0.025649
# rev_101_s    0.017013
# Name: 53, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.001229
# y_1_s      0.002277
# y_2_s      0.001527
# y_3_s      0.001313
# y_4_s      0.001694
#              ...
# y_96_s     0.000222
# y_98_s     0.001039
# y_99_s     0.002651
# y_100_s    0.002544
# y_101_s    0.001328
# Name: 65, Length: 96, dtype: object
# rev_1_s      0.005642
# rev_2_s      0.002512
# rev_3_s      0.002569
# rev_4_s      0.008177
# rev_5_s        0.0021
#                ...
# rev_96_s     0.000671
# rev_98_s     0.003949
# rev_99_s     0.019849
# rev_100_s     0.01066
# rev_101_s    0.004555
# Name: 65, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_38_s']
# y_50_s     0.005493
# y_1_s      0.007002
# y_2_s      0.005966
# y_3_s      0.005533
# y_4_s      0.005959
#              ...
# y_96_s     0.004487
# y_98_s     0.005304
# y_99_s     0.006916
# y_100_s    0.006808
# y_101_s    0.005669
# Name: 79, Length: 96, dtype: object
# rev_1_s      0.017352
# rev_2_s      0.009816
# rev_3_s      0.010824
# rev_4_s      0.028759
# rev_5_s      0.009472
#                ...
# rev_96_s     0.013544
# rev_98_s     0.020161
# rev_99_s     0.051781
# rev_100_s    0.028532
# rev_101_s     0.01944
# Name: 79, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_38_s', 'rev_70_s']
# y_50_s     0.016646
# y_1_s      0.017786
# y_2_s      0.016982
# y_3_s      0.016735
# y_4_s      0.017111
#              ...
# y_96_s     0.015639
# y_98_s     0.016456
# y_99_s     0.018068
# y_100_s    0.017961
# y_101_s     0.01684
# Name: 81, Length: 96, dtype: object
# rev_1_s      0.044074
# rev_2_s      0.027938
# rev_3_s      0.032739
# rev_4_s      0.082583
# rev_5_s      0.028225
#                ...
# rev_96_s     0.047205
# rev_98_s     0.062553
# rev_99_s     0.135283
# rev_100_s    0.075268
# rev_101_s    0.057742
# Name: 81, Length: 95, dtype: object
# ['rev_45_s', 'rev_38_s', 'rev_15_s', 'rev_73_s', 'rev_71_s', 'rev_70_s']
# y_50_s     0.003774
# y_1_s      0.004608
# y_2_s      0.004317
# y_3_s       0.00402
# y_4_s       0.00424
#              ...
# y_96_s     0.002768
# y_98_s     0.003585
# y_99_s     0.005196
# y_100_s    0.005089
# y_101_s    0.003776
# Name: 82, Length: 96, dtype: object
# rev_1_s      0.011418
# rev_2_s      0.007102
# rev_3_s      0.007865
# rev_4_s      0.020462
# rev_5_s      0.006704
#                ...
# rev_96_s     0.008355
# rev_98_s     0.013626
# rev_99_s     0.038909
# rev_100_s    0.021328
# rev_101_s    0.012946
# Name: 82, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.003873
# y_1_s      0.004102
# y_2_s       0.00419
# y_3_s      0.003893
# y_4_s      0.003829
#              ...
# y_96_s     0.003109
# y_98_s     0.002564
# y_99_s     0.004037
# y_100_s    0.003356
# y_101_s    0.003153
# Name: 1, Length: 96, dtype: object
# rev_1_s      0.010166
# rev_2_s      0.006894
# rev_3_s      0.007617
# rev_4_s      0.018481
# rev_5_s      0.006992
#                ...
# rev_96_s     0.009384
# rev_98_s     0.009746
# rev_99_s     0.030231
# rev_100_s    0.014064
# rev_101_s    0.010812
# Name: 1, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_73_s', 'rev_70_s', 'rev_38_s', 'rev_71_s', 'rev_87_s', 'rev_94_s', 'rev_99_s', 'rev_80_s', 'rev_66_s', 'rev_31_s', 'rev_49_s', 'rev_18_s', 'rev_26_s']
# y_50_s     0.009525
# y_1_s      0.009762
# y_2_s      0.009843
# y_3_s      0.009546
# y_4_s      0.009481
#              ...
# y_96_s     0.008761
# y_98_s     0.008216
# y_99_s      0.00969
# y_100_s    0.009008
# y_101_s    0.008908
# Name: 2, Length: 96, dtype: object
# rev_1_s      0.024189
# rev_2_s      0.016192
# rev_3_s      0.018675
# rev_4_s       0.04576
# rev_5_s      0.016765
#                ...
# rev_96_s     0.026444
# rev_98_s     0.031231
# rev_99_s     0.072551
# rev_100_s    0.037751
# rev_101_s    0.030543
# Name: 2, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_38_s']
# y_50_s          0.0
# y_1_s       0.00025
# y_2_s      0.000317
# y_3_s       0.00002
# y_4_s           0.0
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000164
# y_100_s         0.0
# y_101_s         0.0
# Name: 12, Length: 96, dtype: object
# rev_1_s       0.00062
# rev_2_s      0.000522
# rev_3_s       0.00004
# rev_4_s           0.0
# rev_5_s      0.000295
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.001231
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 12, Length: 95, dtype: object
# ['rev_80_s', 'rev_45_s', 'rev_18_s', 'rev_94_s', 'rev_70_s', 'rev_73_s', 'rev_31_s', 'rev_83_s', 'rev_23_s', 'rev_42_s']
# y_50_s     0.000554
# y_1_s      0.000871
# y_2_s      0.000871
# y_3_s      0.000575
# y_4_s       0.00051
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000719
# y_100_s    0.000037
# y_101_s         0.0
# Name: 22, Length: 96, dtype: object
# rev_1_s      0.002159
# rev_2_s      0.001434
# rev_3_s      0.001124
# rev_4_s      0.002463
# rev_5_s      0.001253
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.005381
# rev_100_s    0.000155
# rev_101_s         0.0
# Name: 22, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_73_s', 'rev_94_s', 'rev_18_s']
# y_50_s     0.008946
# y_1_s      0.009193
# y_2_s      0.009263
# y_3_s      0.008966
# y_4_s      0.008902
#              ...
# y_96_s     0.008182
# y_98_s     0.007637
# y_99_s      0.00911
# y_100_s    0.008429
# y_101_s    0.008412
# Name: 29, Length: 96, dtype: object
# rev_1_s       0.02278
# rev_2_s      0.015239
# rev_3_s      0.017542
# rev_4_s      0.042965
# rev_5_s      0.015764
#                ...
# rev_96_s     0.024696
# rev_98_s      0.02903
# rev_99_s     0.068215
# rev_100_s    0.035323
# rev_101_s    0.028845
# Name: 29, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004901
# y_1_s      0.005236
# y_2_s      0.005218
# y_3_s      0.004921
# y_4_s      0.004857
#              ...
# y_96_s     0.004137
# y_98_s     0.003592
# y_99_s     0.005065
# y_100_s    0.004384
# y_101_s    0.004234
# Name: 37, Length: 96, dtype: object
# rev_1_s      0.012976
# rev_2_s      0.008585
# rev_3_s      0.009628
# rev_4_s      0.023442
# rev_5_s       0.00877
#                ...
# rev_96_s     0.012487
# rev_98_s     0.013654
# rev_99_s     0.037928
# rev_100_s    0.018372
# rev_101_s    0.014517
# Name: 37, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_70_s', 'rev_15_s']
# y_50_s     0.005558
# y_1_s      0.005947
# y_2_s      0.005875
# y_3_s      0.005578
# y_4_s      0.005514
#              ...
# y_96_s     0.004794
# y_98_s     0.004248
# y_99_s     0.005722
# y_100_s     0.00504
# y_101_s    0.004921
# Name: 41, Length: 96, dtype: object
# rev_1_s      0.014736
# rev_2_s      0.009665
# rev_3_s      0.010912
# rev_4_s      0.026611
# rev_5_s      0.009905
#                ...
# rev_96_s     0.014469
# rev_98_s     0.016149
# rev_99_s     0.042843
# rev_100_s    0.021123
# rev_101_s    0.016873
# Name: 41, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s']
# y_50_s          0.0
# y_1_s      0.000356
# y_2_s      0.000317
# y_3_s       0.00002
# y_4_s           0.0
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000164
# y_100_s         0.0
# y_101_s         0.0
# Name: 54, Length: 96, dtype: object
# rev_1_s      0.000883
# rev_2_s      0.000522
# rev_3_s       0.00004
# rev_4_s           0.0
# rev_5_s      0.000295
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.001231
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 54, Length: 95, dtype: object
# ['rev_80_s', 'rev_45_s', 'rev_18_s', 'rev_94_s']
# y_50_s     0.007723
# y_1_s      0.008008
# y_2_s       0.00804
# y_3_s      0.007743
# y_4_s      0.007679
#              ...
# y_96_s     0.006959
# y_98_s     0.006414
# y_99_s     0.007887
# y_100_s    0.007206
# y_101_s    0.007065
# Name: 56, Length: 96, dtype: object
# rev_1_s      0.019844
# rev_2_s      0.013227
# rev_3_s      0.015149
# rev_4_s      0.037062
# rev_5_s      0.013649
#                ...
# rev_96_s     0.021005
# rev_98_s     0.024381
# rev_99_s     0.059057
# rev_100_s    0.030198
# rev_101_s    0.024227
# Name: 56, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_38_s', 'rev_73_s', 'rev_70_s']
# Step 2 of repeat 1 finished in 0.21099099999992177 seconds!
# Step 3 of repeat 1 finished in 0.21520429999986845 seconds!
# Step 4 of repeat 1 finished in 0.24973479999994197 seconds!
# Repeat 1  finished in  83.70683860000008 seconds!
#
#
#  --->Repeat #2:
# finished calculating te's for rank 101 in 37.98258409999994 seconds
# finished calculating te's for rank 101 in 38.35341339999991 seconds
# Step 1 of repeat 2 finished in 83.25294289999988 seconds!
# y_50_s     0.005196
# y_1_s       0.00616
# y_2_s      0.005597
# y_3_s      0.005148
# y_4_s      0.005661
#              ...
# y_96_s     0.004189
# y_98_s     0.005006
# y_99_s     0.006618
# y_100_s    0.006511
# y_101_s     0.00512
# Name: 6, Length: 96, dtype: object
# rev_1_s      0.015264
# rev_2_s      0.009208
# rev_3_s      0.010072
# rev_4_s      0.027322
# rev_5_s      0.009571
#                ...
# rev_96_s     0.012645
# rev_98_s     0.019028
# rev_99_s     0.049551
# rev_100_s    0.027284
# rev_101_s    0.017556
# Name: 6, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004699
# y_1_s      0.005458
# y_2_s      0.005013
# y_3_s      0.004682
# y_4_s      0.005165
#              ...
# y_96_s     0.003693
# y_98_s      0.00451
# y_99_s     0.006122
# y_100_s    0.006014
# y_101_s    0.004652
# Name: 8, Length: 96, dtype: object
# rev_1_s      0.013525
# rev_2_s      0.008248
# rev_3_s       0.00916
# rev_4_s      0.024927
# rev_5_s      0.009166
#                ...
# rev_96_s     0.011147
# rev_98_s     0.017142
# rev_99_s     0.045835
# rev_100_s    0.025204
# rev_101_s    0.015953
# Name: 8, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.003131
# y_1_s      0.003906
# y_2_s      0.003469
# y_3_s      0.003308
# y_4_s      0.003597
#              ...
# y_96_s     0.002125
# y_98_s     0.002942
# y_99_s     0.004554
# y_100_s    0.004446
# y_101_s    0.003049
# Name: 31, Length: 96, dtype: object
# rev_1_s      0.009679
# rev_2_s      0.005706
# rev_3_s      0.006472
# rev_4_s       0.01736
# rev_5_s      0.006173
#                ...
# rev_96_s     0.006414
# rev_98_s     0.011182
# rev_99_s     0.034095
# rev_100_s    0.018634
# rev_101_s    0.010455
# Name: 31, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.000586
# y_1_s      0.001804
# y_2_s      0.000989
# y_3_s      0.000773
# y_4_s      0.001051
#              ...
# y_96_s          0.0
# y_98_s     0.000396
# y_99_s     0.002008
# y_100_s    0.001901
# y_101_s    0.000597
# Name: 39, Length: 96, dtype: object
# rev_1_s       0.00447
# rev_2_s      0.001627
# rev_3_s      0.001513
# rev_4_s      0.005075
# rev_5_s      0.000685
#                ...
# rev_96_s          0.0
# rev_98_s     0.001506
# rev_99_s     0.015037
# rev_100_s    0.007967
# rev_101_s    0.002046
# Name: 39, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s']
# y_50_s     0.000821
# y_1_s      0.001964
# y_2_s      0.001261
# y_3_s      0.000963
# y_4_s      0.001286
#              ...
# y_96_s          0.0
# y_98_s     0.000631
# y_99_s     0.002243
# y_100_s    0.002136
# y_101_s    0.000765
# Name: 40, Length: 96, dtype: object
# rev_1_s      0.004867
# rev_2_s      0.002074
# rev_3_s      0.001885
# rev_4_s      0.006207
# rev_5_s      0.001339
#                ...
# rev_96_s          0.0
# rev_98_s     0.002398
# rev_99_s     0.016793
# rev_100_s     0.00895
# rev_101_s    0.002622
# Name: 40, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s']
# y_50_s     0.010683
# y_1_s      0.011665
# y_2_s      0.010872
# y_3_s      0.010796
# y_4_s      0.011148
#              ...
# y_96_s     0.009676
# y_98_s     0.010493
# y_99_s     0.012105
# y_100_s    0.011998
# y_101_s    0.010845
# Name: 51, Length: 96, dtype: object
# rev_1_s      0.028905
# rev_2_s      0.017886
# rev_3_s       0.02112
# rev_4_s      0.053804
# rev_5_s      0.019437
#                ...
# rev_96_s     0.029206
# rev_98_s     0.039886
# rev_99_s     0.090635
# rev_100_s    0.050279
# rev_101_s    0.037188
# Name: 51, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.001145
# y_1_s      0.001764
# y_2_s      0.001333
# y_3_s       0.00108
# y_4_s       0.00161
#              ...
# y_96_s     0.000139
# y_98_s     0.000955
# y_99_s     0.002567
# y_100_s     0.00246
# y_101_s    0.001285
# Name: 76, Length: 96, dtype: object
# rev_1_s      0.004371
# rev_2_s      0.002194
# rev_3_s      0.002113
# rev_4_s      0.007772
# rev_5_s      0.002849
#                ...
# rev_96_s     0.000418
# rev_98_s     0.003631
# rev_99_s     0.019221
# rev_100_s    0.010309
# rev_101_s    0.004408
# Name: 76, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s']
# y_50_s     0.000944
# y_1_s      0.001257
# y_2_s      0.001261
# y_3_s      0.000964
# y_4_s        0.0009
#              ...
# y_96_s      0.00018
# y_98_s          0.0
# y_99_s     0.001108
# y_100_s    0.000427
# y_101_s    0.000396
# Name: 0, Length: 96, dtype: object
# rev_1_s      0.003116
# rev_2_s      0.002075
# rev_3_s      0.001887
# rev_4_s      0.004344
# rev_5_s      0.001927
#                ...
# rev_96_s     0.000543
# rev_98_s          0.0
# rev_99_s     0.008299
# rev_100_s    0.001789
# rev_101_s    0.001357
# Name: 0, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_73_s', 'rev_94_s', 'rev_18_s']
# y_50_s     0.005496
# y_1_s      0.005986
# y_2_s      0.005814
# y_3_s      0.005517
# y_4_s      0.005452
#              ...
# y_96_s     0.004732
# y_98_s     0.004187
# y_99_s     0.005661
# y_100_s    0.004979
# y_101_s    0.004819
# Name: 3, Length: 96, dtype: object
# rev_1_s      0.014832
# rev_2_s      0.009564
# rev_3_s      0.010793
# rev_4_s      0.026315
# rev_5_s      0.009799
#                ...
# rev_96_s     0.014284
# rev_98_s     0.015916
# rev_99_s     0.042385
# rev_100_s    0.020866
# rev_101_s    0.016525
# Name: 3, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.000443
# y_1_s       0.00076
# y_2_s       0.00076
# y_3_s      0.000463
# y_4_s      0.000399
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000607
# y_100_s         0.0
# y_101_s         0.0
# Name: 26, Length: 96, dtype: object
# rev_1_s      0.001883
# rev_2_s       0.00125
# rev_3_s      0.000906
# rev_4_s      0.001924
# rev_5_s       0.00106
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.004545
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 26, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_94_s', 'rev_73_s', 'rev_18_s', 'rev_31_s']
# y_50_s     0.000177
# y_1_s       0.00039
# y_2_s      0.000494
# y_3_s      0.000197
# y_4_s      0.000133
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000341
# y_100_s         0.0
# y_101_s         0.0
# Name: 48, Length: 96, dtype: object
# rev_1_s      0.000966
# rev_2_s      0.000813
# rev_3_s      0.000386
# rev_4_s      0.000643
# rev_5_s      0.000601
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.002557
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 48, Length: 95, dtype: object
# ['rev_80_s', 'rev_45_s', 'rev_94_s', 'rev_70_s', 'rev_18_s']
# y_50_s      0.00521
# y_1_s      0.005509
# y_2_s      0.005527
# y_3_s       0.00523
# y_4_s      0.005166
#              ...
# y_96_s     0.004446
# y_98_s       0.0039
# y_99_s     0.005374
# y_100_s    0.004692
# y_101_s    0.004478
# Name: 57, Length: 96, dtype: object
# rev_1_s       0.01365
# rev_2_s      0.009092
# rev_3_s      0.010232
# rev_4_s      0.024931
# rev_5_s      0.009303
#                ...
# rev_96_s     0.013418
# rev_98_s     0.014826
# rev_99_s     0.040238
# rev_100_s    0.019665
# rev_101_s    0.015355
# Name: 57, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_73_s', 'rev_70_s', 'rev_38_s']
# y_50_s     0.007737
# y_1_s      0.007938
# y_2_s      0.008054
# y_3_s      0.007758
# y_4_s      0.007693
#              ...
# y_96_s     0.006973
# y_98_s     0.006428
# y_99_s     0.007902
# y_100_s     0.00722
# y_101_s    0.007019
# Name: 80, Length: 96, dtype: object
# rev_1_s       0.01967
# rev_2_s       0.01325
# rev_3_s      0.015177
# rev_4_s       0.03713
# rev_5_s      0.013674
#                ...
# rev_96_s     0.021047
# rev_98_s     0.024434
# rev_99_s     0.059163
# rev_100_s    0.030257
# rev_101_s    0.024069
# Name: 80, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_38_s', 'rev_73_s', 'rev_70_s', 'rev_71_s', 'rev_87_s', 'rev_49_s', 'rev_99_s', 'rev_66_s']
# Step 2 of repeat 2 finished in 0.14404790000003231 seconds!
# Step 3 of repeat 2 finished in 0.11962220000009438 seconds!
# Step 4 of repeat 2 finished in 0.141038700000081 seconds!
# Repeat 2  finished in  83.65796369999998 seconds!
#
#
#  --->Repeat #3:
# finished calculating te's for rank 101 in 38.851976599999944 seconds
# finished calculating te's for rank 101 in 39.21144909999998 seconds
# Step 1 of repeat 3 finished in 84.4036916 seconds!
# y_50_s     0.003743
# y_1_s      0.004306
# y_2_s       0.00398
# y_3_s      0.003637
# y_4_s      0.004209
#              ...
# y_96_s     0.002737
# y_98_s     0.003554
# y_99_s     0.005166
# y_100_s    0.005058
# y_101_s    0.003909
# Name: 4, Length: 96, dtype: object
# rev_1_s      0.010669
# rev_2_s      0.006548
# rev_3_s      0.007115
# rev_4_s      0.020313
# rev_5_s      0.007029
#                ...
# rev_96_s     0.008262
# rev_98_s     0.013508
# rev_99_s     0.038678
# rev_100_s    0.021198
# rev_101_s    0.013402
# Name: 4, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.000469
# y_1_s      0.001742
# y_2_s      0.000816
# y_3_s        0.0007
# y_4_s      0.000934
#              ...
# y_96_s          0.0
# y_98_s     0.000279
# y_99_s     0.001891
# y_100_s    0.001784
# y_101_s    0.000482
# Name: 35, Length: 96, dtype: object
# rev_1_s      0.004317
# rev_2_s      0.001343
# rev_3_s       0.00137
# rev_4_s      0.004508
# rev_5_s      0.000287
#                ...
# rev_96_s          0.0
# rev_98_s      0.00106
# rev_99_s     0.014157
# rev_100_s    0.007474
# rev_101_s    0.001651
# Name: 35, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s']
# y_50_s     0.000895
# y_1_s      0.002014
# y_2_s      0.001292
# y_3_s      0.001069
# y_4_s       0.00136
#              ...
# y_96_s          0.0
# y_98_s     0.000705
# y_99_s     0.002317
# y_100_s     0.00221
# y_101_s    0.000668
# Name: 42, Length: 96, dtype: object
# rev_1_s       0.00499
# rev_2_s      0.002126
# rev_3_s      0.002091
# rev_4_s      0.006564
# rev_5_s      0.001456
#                ...
# rev_96_s          0.0
# rev_98_s     0.002679
# rev_99_s     0.017347
# rev_100_s     0.00926
# rev_101_s    0.002291
# Name: 42, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s']
# y_50_s     0.007681
# y_1_s      0.008346
# y_2_s      0.008073
# y_3_s      0.007712
# y_4_s      0.008147
#              ...
# y_96_s     0.006675
# y_98_s     0.007491
# y_99_s     0.009103
# y_100_s    0.008996
# y_101_s    0.007763
# Name: 70, Length: 96, dtype: object
# rev_1_s      0.020682
# rev_2_s      0.013282
# rev_3_s      0.015087
# rev_4_s      0.039318
# rev_5_s      0.013007
#                ...
# rev_96_s     0.020147
# rev_98_s     0.028477
# rev_99_s     0.068162
# rev_100_s    0.037701
# rev_101_s    0.026617
# Name: 70, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.006897
# y_1_s      0.007383
# y_2_s      0.007215
# y_3_s      0.006918
# y_4_s      0.006854
#              ...
# y_96_s     0.006133
# y_98_s     0.005588
# y_99_s     0.007062
# y_100_s     0.00638
# y_101_s    0.006061
# Name: 7, Length: 96, dtype: object
# rev_1_s      0.018294
# rev_2_s      0.011869
# rev_3_s      0.013534
# rev_4_s      0.033077
# rev_5_s      0.012222
#                ...
# rev_96_s     0.018513
# rev_98_s     0.021242
# rev_99_s     0.052876
# rev_100_s    0.026738
# rev_101_s    0.020781
# Name: 7, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s']
# y_50_s     0.001005
# y_1_s      0.001307
# y_2_s      0.001322
# y_3_s      0.001025
# y_4_s      0.000961
#              ...
# y_96_s     0.000241
# y_98_s          0.0
# y_99_s     0.001169
# y_100_s    0.000488
# y_101_s     0.00045
# Name: 13, Length: 96, dtype: object
# rev_1_s      0.003239
# rev_2_s      0.002175
# rev_3_s      0.002005
# rev_4_s      0.004637
# rev_5_s      0.002032
#                ...
# rev_96_s     0.000726
# rev_98_s          0.0
# rev_99_s     0.008754
# rev_100_s    0.002043
# rev_101_s    0.001542
# Name: 13, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_73_s', 'rev_94_s']
# y_50_s     0.000177
# y_1_s       0.00039
# y_2_s      0.000494
# y_3_s      0.000197
# y_4_s      0.000133
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000341
# y_100_s         0.0
# y_101_s         0.0
# Name: 49, Length: 96, dtype: object
# rev_1_s      0.000966
# rev_2_s      0.000813
# rev_3_s      0.000386
# rev_4_s      0.000643
# rev_5_s      0.000601
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.002557
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 49, Length: 95, dtype: object
# ['rev_80_s', 'rev_45_s', 'rev_94_s', 'rev_70_s', 'rev_18_s']
# y_50_s      0.00882
# y_1_s      0.009274
# y_2_s      0.009137
# y_3_s       0.00884
# y_4_s      0.008776
#              ...
# y_96_s     0.008056
# y_98_s     0.007511
# y_99_s     0.008984
# y_100_s    0.008303
# y_101_s    0.007982
# Name: 52, Length: 96, dtype: object
# rev_1_s       0.02298
# rev_2_s      0.015031
# rev_3_s      0.017294
# rev_4_s      0.042355
# rev_5_s      0.015545
#                ...
# rev_96_s     0.024315
# rev_98_s     0.028549
# rev_99_s     0.067269
# rev_100_s    0.034794
# rev_101_s    0.027371
# Name: 52, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s      0.00521
# y_1_s      0.005509
# y_2_s      0.005527
# y_3_s       0.00523
# y_4_s      0.005166
#              ...
# y_96_s     0.004446
# y_98_s       0.0039
# y_99_s     0.005374
# y_100_s    0.004692
# y_101_s    0.004478
# Name: 55, Length: 96, dtype: object
# rev_1_s       0.01365
# rev_2_s      0.009092
# rev_3_s      0.010232
# rev_4_s      0.024931
# rev_5_s      0.009303
#                ...
# rev_96_s     0.013418
# rev_98_s     0.014826
# rev_99_s     0.040238
# rev_100_s    0.019665
# rev_101_s    0.015355
# Name: 55, Length: 95, dtype: object
# ['rev_45_s', 'rev_15_s', 'rev_73_s', 'rev_70_s', 'rev_38_s']
# Step 2 of repeat 3 finished in 0.749760599999945 seconds!
# Step 3 of repeat 3 finished in 0.10953689999996641 seconds!
# Step 4 of repeat 3 finished in 0.12913090000006378 seconds!
# Repeat 3  finished in  85.39264089999983 seconds!
#
#
#  --->Repeat #4:
# finished calculating te's for rank 101 in 38.01970970000002 seconds
# finished calculating te's for rank 101 in 37.61270609999997 seconds
# Step 1 of repeat 4 finished in 82.58808840000006 seconds!
# y_50_s       0.0073
# y_1_s      0.008331
# y_2_s      0.007702
# y_3_s      0.007387
# y_4_s      0.007765
#              ...
# y_96_s     0.006294
# y_98_s      0.00711
# y_99_s     0.008722
# y_100_s    0.008615
# y_101_s    0.007466
# Name: 47, Length: 96, dtype: object
# rev_1_s      0.020644
# rev_2_s      0.012671
# rev_3_s      0.014451
# rev_4_s      0.037478
# rev_5_s      0.012968
#                ...
# rev_96_s     0.018996
# rev_98_s     0.027027
# rev_99_s     0.065306
# rev_100_s    0.036103
# rev_101_s    0.025602
# Name: 47, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.002446
# y_1_s      0.003093
# y_2_s      0.002704
# y_3_s      0.002434
# y_4_s      0.002911
#              ...
# y_96_s     0.001439
# y_98_s     0.002256
# y_99_s     0.003868
# y_100_s    0.003761
# y_101_s    0.002549
# Name: 75, Length: 96, dtype: object
# rev_1_s      0.007664
# rev_2_s      0.004449
# rev_3_s      0.004761
# rev_4_s       0.01405
# rev_5_s      0.003954
#                ...
# rev_96_s     0.004345
# rev_98_s     0.008575
# rev_99_s     0.028961
# rev_100_s     0.01576
# rev_101_s    0.008741
# Name: 75, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.000748
# y_1_s      0.001037
# y_2_s      0.001066
# y_3_s      0.000769
# y_4_s      0.000705
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000913
# y_100_s    0.000231
# y_101_s    0.000091
# Name: 14, Length: 96, dtype: object
# rev_1_s       0.00257
# rev_2_s      0.001753
# rev_3_s      0.001504
# rev_4_s      0.003401
# rev_5_s      0.001589
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.006835
# rev_100_s     0.00097
# rev_101_s    0.000311
# Name: 14, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_73_s', 'rev_94_s', 'rev_18_s', 'rev_31_s', 'rev_83_s']
# y_50_s          0.0
# y_1_s      0.000192
# y_2_s      0.000317
# y_3_s       0.00002
# y_4_s           0.0
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000164
# y_100_s         0.0
# y_101_s         0.0
# Name: 32, Length: 96, dtype: object
# rev_1_s      0.000476
# rev_2_s      0.000522
# rev_3_s       0.00004
# rev_4_s           0.0
# rev_5_s      0.000295
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.001231
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 32, Length: 95, dtype: object
# ['rev_80_s', 'rev_45_s', 'rev_18_s', 'rev_94_s', 'rev_70_s', 'rev_73_s', 'rev_31_s', 'rev_83_s']
# Step 2 of repeat 4 finished in 0.7319780999998784 seconds!
# Step 3 of repeat 4 finished in 0.07806559999994533 seconds!
# Step 4 of repeat 4 finished in 0.0982438999999431 seconds!
# Repeat 4  finished in  83.49661690000016 seconds!
#
#
#  --->Repeat #5:
# finished calculating te's for rank 101 in 37.45762310000009 seconds
# finished calculating te's for rank 101 in 38.216058400000065 seconds
# Step 1 of repeat 5 finished in 83.33480490000011 seconds!
# y_50_s       0.0073
# y_1_s      0.008313
# y_2_s      0.007702
# y_3_s      0.007255
# y_4_s      0.007765
#              ...
# y_96_s     0.006294
# y_98_s      0.00711
# y_99_s     0.008722
# y_100_s    0.008615
# y_101_s    0.007466
# Name: 44, Length: 96, dtype: object
# rev_1_s        0.0206
# rev_2_s      0.012671
# rev_3_s      0.014193
# rev_4_s      0.037478
# rev_5_s      0.013042
#                ...
# rev_96_s     0.018996
# rev_98_s     0.027027
# rev_99_s     0.065306
# rev_100_s    0.036103
# rev_101_s      0.0256
# Name: 44, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.007681
# y_1_s      0.008328
# y_2_s       0.00794
# y_3_s      0.007669
# y_4_s      0.008147
#              ...
# y_96_s     0.006675
# y_98_s     0.007491
# y_99_s     0.009103
# y_100_s    0.008996
# y_101_s    0.007785
# Name: 59, Length: 96, dtype: object
# rev_1_s      0.020637
# rev_2_s      0.013062
# rev_3_s      0.015004
# rev_4_s      0.039318
# rev_5_s      0.013007
#                ...
# rev_96_s     0.020147
# rev_98_s     0.028477
# rev_99_s     0.068162
# rev_100_s    0.037701
# rev_101_s    0.026692
# Name: 59, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.001408
# y_1_s      0.001725
# y_2_s      0.001725
# y_3_s      0.001428
# y_4_s      0.001364
#              ...
# y_96_s     0.000643
# y_98_s     0.000098
# y_99_s     0.001572
# y_100_s     0.00089
# y_101_s    0.000763
# Name: 16, Length: 96, dtype: object
# rev_1_s      0.004274
# rev_2_s      0.002838
# rev_3_s      0.002794
# rev_4_s      0.006581
# rev_5_s      0.002729
#                ...
# rev_96_s     0.001942
# rev_98_s     0.000374
# rev_99_s      0.01177
# rev_100_s    0.003731
# rev_101_s    0.002617
# Name: 16, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_73_s', 'rev_94_s', 'rev_18_s', 'rev_31_s']
# y_50_s     0.000374
# y_1_s      0.000632
# y_2_s      0.000692
# y_3_s      0.000395
# y_4_s      0.000331
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.000539
# y_100_s         0.0
# y_101_s         0.0
# Name: 34, Length: 96, dtype: object
# rev_1_s      0.001565
# rev_2_s      0.001138
# rev_3_s      0.000773
# rev_4_s      0.001596
# rev_5_s      0.000943
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.004035
# rev_100_s         0.0
# rev_101_s         0.0
# Name: 34, Length: 95, dtype: object
# ['rev_45_s', 'rev_80_s', 'rev_70_s', 'rev_94_s', 'rev_73_s', 'rev_18_s', 'rev_31_s', 'rev_83_s']
# Step 2 of repeat 5 finished in 0.07907249999993837 seconds!
# Step 3 of repeat 5 finished in 0.06930849999980637 seconds!
# Step 4 of repeat 5 finished in 0.08090730000003532 seconds!
# Repeat 5  finished in  83.56461259999992 seconds!
#
#
#  --->Repeat #6:
# finished calculating te's for rank 101 in 37.52891060000002 seconds
# finished calculating te's for rank 101 in 39.745704099999784 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 simulate_duopoly(data, vals_data, criteria)
#
# Cell In[3], line 25, in simulate_duopoly(data, vals_data, criteria)
#      23 calc_split_tes(data, split_no=config.split_no_2, user_visit_no=i, ranks_list=config.ranks_list)
#      24 calc_base_ad_split_ctr(data,split_no=config.split_no_2, user_visit_no=i)
# ---> 25 calc_split_ctrs(data, vals_data, split_no=config.split_no_2, user_visit_no=i, ranks_list=config.ranks_list)
#      27 finish_time = time.perf_counter()
#      28 print(f"Step 1 of repeat {i} finished in {finish_time - start_time} seconds!")
#
# File c:\Users\ma59396\OneDrive - The University of Texas at Austin\Projects\online_ads\scripts\utils.py:621, in calc_split_ctrs(data, vals_data, split_no, user_visit_no, ranks_list)
#     616 y_base_ad_actual = f'y_{base_ad}'
#     617 rev_var_name_actual = f'rev_{rank}'
# --> 621 if (len(data[(data['user_visit_no'] == user_visit_no) & (data['split'] == split_no)]) > 0):
#     622     # calc ctr for split data
#     623     data.loc[(data['user_visit_no'] == user_visit_no) & (data['split'] == split_no), y_var_name_split] = data.loc[(data['user_visit_no'] == user_visit_no) & (data['split'] == split_no), te_var_name_split] + data.loc[(data['user_visit_no'] == user_visit_no) & (data['split'] == split_no), y_base_ad_split]
#     624     # set y_{rank} to 0 if it is negative
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\frame.py:3811, in DataFrame._getitem_bool_array(self, key)
#    3808     return self.copy(deep=None)
#    3810 indexer = key.nonzero()[0]
# -> 3811 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\generic.py:3948, in NDFrame._take_with_is_copy(self, indices, axis)
#    3940 def _take_with_is_copy(self: NDFrameT, indices, axis: Axis = 0) -> NDFrameT:
#    3941     """
#    3942     Internal version of the `take` method that sets the `_is_copy`
#    3943     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3946     See the docstring of `take` for full explanation of the parameters.
#    3947     """
# -> 3948     result = self._take(indices=indices, axis=axis)
#    3949     # Maybe set copy if we didn't actually change the index.
#    3950     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\internals\managers.py:963, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
# --> 963 return self.reindex_indexer(
#     964     new_axis=new_labels,
#     965     indexer=indexer,
#     966     axis=axis,
#     967     allow_dups=True,
#     968     copy=None,
#     969 )
#
# File c:\Users\ma59396\AppData\Local\anaconda3\envs\online_ads\lib\site-packages\pandas\core\internals\managers.py:758, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     746 else:
#     747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#    (...)
#     755         for blk in self.blocks
#     756     ]
# --> 758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#     761 new_mgr = type(self).from_blocks(new_blocks, new_axes)
#
# KeyboardInterrupt:

# %%
# a) calc TEs and CTRs on s1
calc_split_tes(data, split_no=config.split_no_1, user_visit_no=1, ranks_list=config.ranks_list)
calc_base_ad_split_ctr(data, split_no=config.split_no_1, user_visit_no=1)
calc_split_ctrs(data, vals_data, split_no=config.split_no_1, user_visit_no=1, ranks_list=config.ranks_list)

# b) calc TEs and CTRs on s2
calc_split_tes(data, split_no=config.split_no_2, user_visit_no=1, ranks_list=config.ranks_list)
calc_base_ad_split_ctr(data,split_no=config.split_no_2, user_visit_no=1)
calc_split_ctrs(data, vals_data, split_no=config.split_no_2, user_visit_no=1, ranks_list=config.ranks_list)
# Out:
# finished calculating te's for rank 101 in 27.451940000000008 seconds
# finished calculating te's for rank 101 in 36.130911999999995 seconds

# %%
create_chosen_ad_columns_split(data, split_no=config.split_no_1, user_visit_no=1, criteria=criteria)
# Out:
# y_50_s     0.005163
# y_1_s      0.006136
# y_2_s       0.00559
# y_3_s      0.005154
# y_4_s      0.005629
#              ...
# y_96_s     0.004157
# y_98_s     0.004973
# y_99_s     0.006585
# y_100_s    0.006478
# y_101_s    0.005267
# Name: 5, Length: 96, dtype: object
# rev_1_s      0.015206
# rev_2_s      0.009196
# rev_3_s      0.010083
# rev_4_s      0.027165
# rev_5_s      0.009474
#                ...
# rev_96_s     0.012547
# rev_98_s     0.018905
# rev_99_s     0.049308
# rev_100_s    0.027148
# rev_101_s    0.018059
# Name: 5, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s          0.0
# y_1_s      0.000947
# y_2_s      0.000409
# y_3_s      0.000334
# y_4_s      0.000465
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.001422
# y_100_s    0.001315
# y_101_s         0.0
# Name: 9, Length: 96, dtype: object
# rev_1_s      0.002345
# rev_2_s      0.000673
# rev_3_s      0.000653
# rev_4_s      0.002246
# rev_5_s           0.0
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.010649
# rev_100_s    0.005511
# rev_101_s         0.0
# Name: 9, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_20_s', 'rev_68_s', 'rev_44_s', 'rev_38_s', 'rev_66_s', 'rev_87_s', 'rev_100_s', 'rev_83_s', 'rev_75_s', 'rev_78_s', 'rev_30_s']
# y_50_s     0.001685
# y_1_s       0.00281
# y_2_s      0.001934
# y_3_s      0.001838
# y_4_s      0.002151
#              ...
# y_96_s     0.000679
# y_98_s     0.001496
# y_99_s     0.003107
# y_100_s       0.003
# y_101_s    0.001806
# Name: 10, Length: 96, dtype: object
# rev_1_s      0.006962
# rev_2_s      0.003181
# rev_3_s      0.003596
# rev_4_s       0.01038
# rev_5_s      0.002335
#                ...
# rev_96_s     0.002049
# rev_98_s     0.005685
# rev_99_s     0.023267
# rev_100_s    0.012573
# rev_101_s    0.006192
# Name: 10, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_70_s', 'rev_38_s', 'rev_99_s', 'rev_87_s', 'rev_66_s', 'rev_20_s']
# y_50_s          0.0
# y_1_s      0.001115
# y_2_s      0.000225
# y_3_s       0.00035
# y_4_s      0.000465
#              ...
# y_96_s          0.0
# y_98_s          0.0
# y_99_s     0.001422
# y_100_s    0.001315
# y_101_s    0.000232
# Name: 11, Length: 96, dtype: object
# rev_1_s      0.002762
# rev_2_s       0.00037
# rev_3_s      0.000685
# rev_4_s      0.002246
# rev_5_s           0.0
#                ...
# rev_96_s          0.0
# rev_98_s          0.0
# rev_99_s     0.010649
# rev_100_s    0.005511
# rev_101_s    0.000795
# Name: 11, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_20_s', 'rev_68_s', 'rev_44_s', 'rev_38_s', 'rev_66_s', 'rev_87_s']
# y_50_s     0.001386
# y_1_s      0.002064
# y_2_s      0.001726
# y_3_s      0.001535
# y_4_s      0.001852
#              ...
# y_96_s      0.00038
# y_98_s     0.001196
# y_99_s     0.002808
# y_100_s    0.002701
# y_101_s    0.001284
# Name: 30, Length: 96, dtype: object
# rev_1_s      0.005114
# rev_2_s      0.002839
# rev_3_s      0.003002
# rev_4_s      0.008936
# rev_5_s      0.003156
#                ...
# rev_96_s     0.001147
# rev_98_s     0.004548
# rev_99_s     0.021028
# rev_100_s     0.01132
# rev_101_s    0.004404
# Name: 30, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.002538
# y_1_s      0.003227
# y_2_s       0.00297
# y_3_s       0.00252
# y_4_s      0.003003
#              ...
# y_96_s     0.001532
# y_98_s     0.002348
# y_99_s      0.00396
# y_100_s    0.003853
# y_101_s     0.00261
# Name: 38, Length: 96, dtype: object
# rev_1_s      0.007995
# rev_2_s      0.004886
# rev_3_s       0.00493
# rev_4_s      0.014495
# rev_5_s      0.005353
#                ...
# rev_96_s     0.004623
# rev_98_s     0.008926
# rev_99_s     0.029651
# rev_100_s    0.016146
# rev_101_s    0.008949
# Name: 38, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004283
# y_1_s      0.005795
# y_2_s      0.004734
# y_3_s      0.004487
# y_4_s      0.004749
#              ...
# y_96_s     0.003277
# y_98_s     0.004094
# y_99_s     0.005706
# y_100_s    0.005598
# y_101_s    0.004706
# Name: 43, Length: 96, dtype: object
# rev_1_s       0.01436
# rev_2_s      0.007788
# rev_3_s      0.008777
# rev_4_s      0.022919
# rev_5_s      0.007206
#                ...
# rev_96_s     0.009891
# rev_98_s     0.015561
# rev_99_s     0.042721
# rev_100_s    0.023462
# rev_101_s    0.016137
# Name: 43, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_70_s', 'rev_38_s', 'rev_15_s']
# y_50_s     0.000755
# y_1_s      0.002086
# y_2_s      0.000921
# y_3_s      0.000753
# y_4_s       0.00122
#              ...
# y_96_s          0.0
# y_98_s     0.000565
# y_99_s     0.002177
# y_100_s     0.00207
# y_101_s    0.000814
# Name: 46, Length: 96, dtype: object
# rev_1_s      0.005168
# rev_2_s      0.001516
# rev_3_s      0.001473
# rev_4_s      0.005889
# rev_5_s      0.000622
#                ...
# rev_96_s          0.0
# rev_98_s     0.002147
# rev_99_s       0.0163
# rev_100_s    0.008674
# rev_101_s    0.002792
# Name: 46, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_38_s', 'rev_20_s']
# y_50_s     0.011025
# y_1_s      0.012055
# y_2_s      0.011161
# y_3_s      0.011278
# y_4_s      0.011491
#              ...
# y_96_s     0.010019
# y_98_s     0.010835
# y_99_s     0.012447
# y_100_s     0.01234
# y_101_s    0.011384
# Name: 50, Length: 96, dtype: object
# rev_1_s      0.029872
# rev_2_s      0.018362
# rev_3_s      0.022063
# rev_4_s      0.055457
# rev_5_s      0.019819
#                ...
# rev_96_s      0.03024
# rev_98_s     0.041188
# rev_99_s       0.0932
# rev_100_s    0.051714
# rev_101_s    0.039036
# Name: 50, Length: 95, dtype: object
# ['rev_45_s']
# y_50_s     0.004805
# y_1_s      0.005372
# y_2_s      0.005166
# y_3_s      0.004812
# y_4_s      0.005271
#              ...
# y_96_s     0.003799
# y_98_s     0.004616
# y_99_s     0.006227
# y_100_s     0.00612
# y_101_s    0.004962
# Name: 53, Length: 96, dtype: object
# rev_1_s      0.013312
# rev_2_s      0.008499
# rev_3_s      0.009414
# rev_4_s      0.025438
# rev_5_s      0.009189
#                ...
# rev_96_s     0.011467
# rev_98_s     0.017545
# rev_99_s     0.046628
# rev_100_s    0.025649
# rev_101_s    0.017013
# Name: 53, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']
# y_50_s     0.001229
# y_1_s      0.002277
# y_2_s      0.001527
# y_3_s      0.001313
# y_4_s      0.001694
#              ...
# y_96_s     0.000222
# y_98_s     0.001039
# y_99_s     0.002651
# y_100_s    0.002544
# y_101_s    0.001328
# Name: 65, Length: 96, dtype: object
# rev_1_s      0.005642
# rev_2_s      0.002512
# rev_3_s      0.002569
# rev_4_s      0.008177
# rev_5_s        0.0021
#                ...
# rev_96_s     0.000671
# rev_98_s     0.003949
# rev_99_s     0.019849
# rev_100_s     0.01066
# rev_101_s    0.004555
# Name: 65, Length: 95, dtype: object
# ['rev_73_s', 'rev_45_s', 'rev_70_s', 'rev_99_s', 'rev_38_s']
# y_50_s     0.005493
# y_1_s      0.007002
# y_2_s      0.005966
# y_3_s      0.005533
# y_4_s      0.005959
#              ...
# y_96_s     0.004487
# y_98_s     0.005304
# y_99_s     0.006916
# y_100_s    0.006808
# y_101_s    0.005669
# Name: 79, Length: 96, dtype: object
# rev_1_s      0.017352
# rev_2_s      0.009816
# rev_3_s      0.010824
# rev_4_s      0.028759
# rev_5_s      0.009472
#                ...
# rev_96_s     0.013544
# rev_98_s     0.020161
# rev_99_s     0.051781
# rev_100_s    0.028532
# rev_101_s     0.01944
# Name: 79, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s', 'rev_38_s', 'rev_70_s']
# y_50_s     0.016646
# y_1_s      0.017786
# y_2_s      0.016982
# y_3_s      0.016735
# y_4_s      0.017111
#              ...
# y_96_s     0.015639
# y_98_s     0.016456
# y_99_s     0.018068
# y_100_s    0.017961
# y_101_s     0.01684
# Name: 81, Length: 96, dtype: object
# rev_1_s      0.044074
# rev_2_s      0.027938
# rev_3_s      0.032739
# rev_4_s      0.082583
# rev_5_s      0.028225
#                ...
# rev_96_s     0.047205
# rev_98_s     0.062553
# rev_99_s     0.135283
# rev_100_s    0.075268
# rev_101_s    0.057742
# Name: 81, Length: 95, dtype: object
# ['rev_45_s', 'rev_38_s', 'rev_15_s', 'rev_73_s', 'rev_71_s', 'rev_70_s']
# y_50_s     0.003774
# y_1_s      0.004608
# y_2_s      0.004317
# y_3_s       0.00402
# y_4_s       0.00424
#              ...
# y_96_s     0.002768
# y_98_s     0.003585
# y_99_s     0.005196
# y_100_s    0.005089
# y_101_s    0.003776
# Name: 82, Length: 96, dtype: object
# rev_1_s      0.011418
# rev_2_s      0.007102
# rev_3_s      0.007865
# rev_4_s      0.020462
# rev_5_s      0.006704
#                ...
# rev_96_s     0.008355
# rev_98_s     0.013626
# rev_99_s     0.038909
# rev_100_s    0.021328
# rev_101_s    0.012946
# Name: 82, Length: 95, dtype: object
# ['rev_45_s', 'rev_73_s']

# %%
# last_chosen_ad_name = 'chosen_ad_6'
# data.loc[1, 'chosen_ad_1'] 
data.columns
# Out:
# Index(['global_token_new', 'mobile', 'impression_timestamp',
#        'publisher_rank_sub', 'ads_on_page', 'user_visit_no_s',
#        'user_visit_no_actual_s', 'c_1_s', 'c_2_s', 'c_3_s',
#        ...
#        'rev_99_s', 'rev_99', 'y_100_s', 'y_100', 'rev_100_s', 'rev_100',
#        'y_101_s', 'y_101', 'rev_101_s', 'rev_101'],
#       dtype='object', length=1059)

# %%
# sorted_ads = row[rev_cols.index].sort_values(ascending=False).index.to_list()
# sorted_ads
row = data.loc[1, :]
row
y_cols = row.filter(regex=r'^y_.*_s$', axis=0)
y_cols.sort_values(ascending=False).values[0:15]
# Out:
# array([0.0096171472699594, 0.006198201050081908, 0.005509540414408121,
#        0.0054343158862862374, 0.0051910768885340755, 0.005155984294210044,
#        0.00511785798337319, 0.00497956864950309, 0.004924602773008071,
#        0.004917545630148194, 0.004874013229196629, 0.004828559944670336,
#        0.004826678477374857, 0.0048136091922848494, 0.004793434404420359],
#       dtype=object)

# %%
sorted_ads[0:15]
# Out:
# rev_45_s    0.059453
# rev_15_s    0.041642
# rev_73_s    0.041533
# rev_70_s    0.041426
# rev_38_s    0.037379
# rev_71_s    0.033906
# rev_87_s    0.032053
# rev_94_s    0.031895
# rev_99_s    0.030231
# rev_80_s    0.030004
# rev_66_s    0.029622
# rev_31_s    0.028221
# rev_49_s    0.026664
# rev_18_s    0.025394
# rev_26_s    0.024244
# Name: 1, dtype: object

# %%
sorted_ads = row[rev_cols.index].sort_values(ascending=False)

# %%
y_var_name_split = 'y_2_s'
rev_var_name_split = 'rev_2_s'

data.loc[(data['user_visit_no'] == 1) & (data['split'] == 1), rev_var_name_split] = data.loc[(data['user_visit_no'] == 1) & (data['split'] == 1), y_var_name_split] * vals_data.loc[vals_data['advertiser_rank'] == 2].advertiser_val_cents.squeeze()

# %%
# data['rev_2_s']
vals_data.loc[vals_data['advertiser_rank'] == 2].advertiser_val_cents.squeeze()
# Out:
# 1.6451094
